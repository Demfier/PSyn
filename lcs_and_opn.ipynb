# %%
import pandas as pd
from PSyn import matrix_functions
import os
from IPython.display import display
import json

# %%
root_path = '/home/gaurav/python-scripts/py/scripts/pg_project/BTP-ProgSyn/program_synthesis/data/'
source_files_path = root_path + 'task1/output/source_csvs/'

already_done = map(lambda x: x.split('.')[0], os.listdir(root_path + 'task1/output/opn_dfs/opn_count/'))
source_files = os.listdir(source_files_path)
# source_files = ['welsh-train-low']

# %%
for file in source_files:
    if file in already_done:
        continue
    source_data = pd.read_csv(source_files_path + file)
    del source_data['Unnamed: 0']
    source_data = source_data[source_data['pos'] == 'N'].dropna(axis=1)
    if source_data.empty:
        continue
    del source_data['pos']
    del source_data['card']
    print('Making operation matrix for %s' % file)
    opn_df = matrix_functions.gen_operation_matrix(source_data)
    print('Generated matrix')
    st_dict = dict()
    opn_df_for_dict = opn_df.groupby('source')
    for src, df in opn_df_for_dict:
        df.reset_index(drop=False, inplace=True)
        del df['source']
        del df['index']
        rm_str = df['rem_subs'][0]
        del df['rem_subs']
#         display(df)
        st_dict[src] = {'removed_substring': rm_str,
                        'operation_sequence': df.to_json() }
    with open(root_path + 'task1/output/opn_dfs/op_sequence_dict/' + file + '.json', 'w') as j:
        print('Saved dict')
        json.dump(st_dict, j)
#         display(pd.read_json(st_dict[src]['operation_sequence']))
    # get op count across all source words
    print('Making opn count df')
    group = opn_df.groupby(['opn', 'char', 'lpos', 'rpos']).size().reset_index(name='count')
    group.to_csv(root_path + 'task1/output/opn_dfs/opn_count/' + file + '.csv')
# Out:
# Making operation matrix for slovene-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for polish-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for german-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for polish-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for georgian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for norwegian-nynorsk-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for bengali-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for norwegian-nynorsk-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for latin-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for slovak-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for german-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for quechua-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for norwegian-bokmal-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for lithuanian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for urdu-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for danish-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for bengali-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for quechua-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for german-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for serbo-croatian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for irish-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for armenian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for swedish-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for kurmanji-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for norwegian-bokmal-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for lower-sorbian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for ukrainian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for turkish-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for czech-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for latvian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for albanian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for russian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for armenian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for bulgarian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for northern-sami-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for sorani-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for hungarian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for navajo-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for ukrainian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for urdu-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for hungarian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for danish-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for slovene-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for northern-sami-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for polish-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for faroese-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for georgian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for latin-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for navajo-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for bulgarian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for estonian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for danish-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for serbo-croatian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for hebrew-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for icelandic-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for lower-sorbian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for estonian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for slovak-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for macedonian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for ukrainian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for swedish-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for turkish-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for icelandic-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for russian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for hungarian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for czech-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for finnish-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for urdu-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for lithuanian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for macedonian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for czech-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for bengali-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for romanian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for faroese-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for norwegian-bokmal-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for icelandic-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for northern-sami-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for turkish-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for hebrew-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for latvian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for sorani-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for quechua-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for lower-sorbian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for estonian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for finnish-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for albanian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for macedonian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for serbo-croatian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for irish-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for navajo-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for armenian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for slovene-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for arabic-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for sorani-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for slovak-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for arabic-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for finnish-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for latvian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for arabic-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for faroese-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for swedish-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for romanian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for hebrew-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for romanian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for lithuanian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for bulgarian-train-high
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for russian-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for irish-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for latin-train-low
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for georgian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
# Making operation matrix for albanian-train-medium
# Generated matrix
# Saved dict
# Making opn count df
