# %%
from PSyn import matrix_functions
import pandas as pd
import os
import time
from IPython.display import display

# %%
root_path = '/home/gaurav/python-scripts/py/scripts/pg_project/BTP-ProgSyn/program_synthesis/data/'

bigram_path = root_path + 'task1/output/bigram_dfs/'
bigram_dfs = os.listdir(bigram_path)
for df in bigram_dfs:
    trans_mat = matrix_functions.make_trans_mat(pd.read_pickle(bigram_path + df))
    trans_mat.to_pickle(bigram_path + 'normalized_finnish-train-low.p')
# Out:
# ['t' 'a' 'v' 'r' 'm' 'e' 'k' 'i' 'n' 'u' 's' 'l' 'j' 'o' 'h' 'ö' 'p' 'ä'
#  'g' 'y' 'c' 'f' 'b' 'd' 'š']
# /home/gaurav/python-scripts/py/scripts/pg_project/BTP-ProgSyn/program_synthesis/PSyn/matrix_functions.py:245: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   trans_mat = pd.DataFrame(data=np.zeros(shape=(n, n)), columns=cids, index=cids)

# %%
df = pd.read_pickle(bigram_path + 'normalized_finnish-train-low.p')

# %%
df
# Out:
#              t_0_0        t_0_-1    t_0_-2    t_0_-3        t_0_-4  \
# t_0_0     0.058237  1.681011e-07  0.012073  0.014914  4.970344e-03
# t_0_-1    0.000237  2.366864e-04  0.000237  0.000237  2.366864e-04
# t_0_-2    0.066383  9.245562e-07  0.046852  0.015602  9.245562e-07
# t_0_-3    0.069982  7.889546e-07  0.013315  0.053315  7.889546e-07
# t_0_-4    0.064688  2.191541e-06  0.000002  0.000002  5.542915e-02
# t_0_-5    0.060243  2.040400e-06  0.000002  0.000002  8.518866e-03
# t_0_-6    0.060527  1.793079e-06  0.007497  0.007497  1.793079e-06
# t_0_-7    0.059492  4.733728e-06  0.000005  0.000005  4.733728e-06
# t_0_-8    0.057204  4.551661e-06  0.000005  0.000005  4.551661e-06
# t_0_-9    0.044044  1.740341e-06  0.000002  0.000002  1.740341e-06
# t_0_-10   0.038029  4.551661e-06  0.000005  0.000005  4.551661e-06
# t_0_-11   0.037997  4.551661e-06  0.000005  0.000005  4.551661e-06
# t_0_-12   0.038345  2.275831e-06  0.000002  0.000002  2.275831e-06
# ...
