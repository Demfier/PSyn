# %%
import pandas as pd
import numpy as np
from IPython.display import display
from PSyn import matrix_functions
from PSyn import brain
import os
import time
SOURCE_DATA_PATH = 'data/task1/dev/'
from collections import Counter

# %%
source_files = os.listdir(SOURCE_DATA_PATH)
source = 'polish-train-high'
# source_files = ['polish-train-medium']

start = time.time()
# for source in source_files:
print(source)
prf, total_corect, global_attr, total_entries, correct_inflections, macro_prf = brain.test_model_accuracy(source, classifier='decision_tree', fasttext_test=True)
# print(time.time() - start)
start = time.time()
print('Macro PRF:', )
print('Guessed %d inflections correctly out of %d.\nAccuracy: %f' % (total_corect, total_entries, (total_corect * 100 / float(total_entries))))
# Out:
# polish-train-high
# Total Alphabets:
# {'e', 'o', 'C', 'j', 'i', 'W', 'Ż', 'r', 'ó', 'G', 'd', 'n', 'ą', 'z', 'l', 'ś', 'c', 's', 't', 'ń', 'B', 'm', 'w', 'ę', 'ż', 'ł', 'g', 'ć', 'y', 'b', 'p', 'a', 'k', 'h', 'ź', ' ', 'M', 'u', 'R', 'f'}
# Epsilon: 9.000000
# Ci: 40.000000
# /home/gaurav/python-scripts/py/scripts/pg_project/BTP-ProgSyn/program_synthesis/PSyn/brain.py:421: RuntimeWarning: divide by zero encountered in true_divide
#   fF = 2 / np.sum(1/np.array([pP, rR]))
# /home/gaurav/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ones and zeros 162 12047
# Macro PRF:
# Guessed 181 inflections correctly out of 421.
# Accuracy: 42.992874

# %%
source_files = os.listdir(SOURCE_DATA_PATH)
source = 'polish-train-high'
# source_files = ['polish-train-medium']

start = time.time()
# for source in source_files:
print(source)
prf, total_corect, global_attr, total_entries, correct_inflections, macro_prf = brain.test_model_accuracy(source, classifier='random_forest')
# print(time.time() - start)
start = time.time()
print('Macro PRF:', )
print('Guessed %d inflections correctly out of %d.\nAccuracy: %f' % (total_corect, total_entries, (total_corect * 100 / float(total_entries))))

# %%
global_attr
# Out:
# 0.42992874109263657

# %%
source_csv = open('data/task1/dev/polish-dev', 'r')
dict_for_df = {'source': [], 'target': [], 'source_node': [], 'pos': []}
content = source_csv.readlines()
for line in content:
    row = line.split('\t')
    dict_for_df['source'].append(row[0])
    dict_for_df['target'].append(row[1])
    dict_for_df['source_node'].append(
        row[0] + '-' + row[2].strip().replace(';', '_'))
    dict_for_df['pos'].append(row[2].split(';')[0])
source_df = pd.DataFrame.from_records(dict_for_df)
source_df = source_df[source_df['pos'] == 'N']
idx = source_df.index[source_df['source_node'] == 'Cezar-N_DAT_PL']
list(source_df.loc[idx]['target'])
# Out:
# ['Cezarom']

# %%
o = pd.DataFrame.from_dict(correct_inflections)
ops_ = {}
for key in o.columns.values:
    ops_[key] = []
    for i, _ in enumerate(o[key]):
        if _:
            ops_[key].append(o[key].index.values[i])
t = []
for s_node in list(ops_.keys()):
    idx = source_df.index[source_df['source_node'] == s_node]
    t.append(list(source_df.loc[idx]['target'])[0])
pd.DataFrame.from_dict({'source': list(ops_.keys()), 'opn_sequence': list(ops_.values()), 'target': t})
# Out:
#                                           opn_sequence  \
# 0                               [ins_m_7_1, ins_o_6_0]
# 1                             [del_n_9_-1, ins_e_9_-1]
# 2                                         [ins_a_10_0]
# 3                              [ins_c_9_0, ins_h_10_1]
# 4     [del_o_8_-1, del_ł_7_-2, ins_e_8_-1, ins_l_7_-2]
# 5                             [ins_m_12_1, ins_o_11_0]
# 6                               [ins_w_8_1, ins_ó_7_0]
# 7                               [ins_e_7_0, ins_m_8_1]
# 8                                          [ins_y_7_0]
# 9                [ins_i_10_-5, ins_o_8_-7, ins_w_9_-6]
# 10                                         [ins_y_6_0]
# 11                            [ins_i_13_1, ins_m_12_0]
# 12                            [ins_c_12_0, ins_h_13_1]
# 13    [del_e_8_-2, del_r_9_-1, ins_r_8_-2, ins_y_9_-1]
# 14                                         [ins_y_9_0]
# 15                 [ins_a_9_0, ins_i_11_2, ins_m_10_1]
# 16                            [ins_i_13_1, ins_m_12_0]
# 17                                         [ins_a_7_0]
# 18                   [ins_i_8_2, ins_o_6_0, ins_w_7_1]
# 19                 [ins_a_9_0, ins_c_10_1, ins_h_11_2]
# 20                 [ins_a_9_0, ins_c_10_1, ins_h_11_2]
# 21                   [ins_e_5_1, ins_i_4_0, ins_m_6_2]
# 22                            [del_e_5_-7, ins_u_5_-7]
# 23                                        [ins_e_11_0]
# 24                              [ins_w_9_1, ins_ó_8_0]
# 25                              [ins_e_5_0, ins_m_6_1]
# 26                            [ins_c_10_0, ins_h_11_1]
# 27                  [ins_a_8_0, ins_i_10_2, ins_m_9_1]
# 28                              [ins_e_7_1, ins_i_6_0]
# 29                              [ins_e_8_1, ins_i_7_0]
# ..                                                 ...
# 235                           [ins_c_10_0, ins_h_11_1]
# 236                                        [ins_y_8_0]
# 237                           [ins_w_13_1, ins_ó_12_0]
# 238    [del_t_8_-1, ins_c_8_-1, ins_e_10_1, ins_i_9_0]
# 239             [ins_e_7_-12, ins_i_6_-13, ins_m_21_2]
# 240                                       [ins_u_10_0]
# 241                                        [ins_e_7_0]
# 242                  [ins_a_5_0, ins_i_7_2, ins_m_6_1]
# 243  [del_e_6_-2, del_i_5_-3, del_z_4_-4, del_ń_7_-...
# 244                             [ins_w_6_1, ins_ó_5_0]
# 245                           [del_o_9_-1, ins_a_9_-1]
# 246                         [del_o_11_-1, ins_a_11_-1]
# 247   [del_e_6_-2, del_k_7_-1, ins_i_7_-1, ins_k_6_-2]
# 248                             [ins_i_9_1, ins_m_8_0]
# 249  [del_e_4_-10, del_k_5_-9, ins_a_5_-9, ins_c_16...
# 250    [del_e_8_-1, ins_a_8_-1, ins_c_9_0, ins_h_10_1]
# 251               [ins_a_10_0, ins_i_12_2, ins_m_11_1]
# 252     [del_e_7_-1, ins_a_7_-1, ins_i_9_1, ins_m_8_0]
# 253               [ins_a_11_0, ins_c_12_1, ins_h_13_2]
# 254                             [ins_e_7_1, ins_z_6_0]
# 255                           [del_o_8_-1, ins_a_8_-1]
# 256     [del_o_6_-1, ins_a_6_-1, ins_i_8_1, ins_m_7_0]
# 257               [ins_i_14_2, ins_o_12_0, ins_w_13_1]
# 258     [del_ź_6_-1, ins_a_8_1, ins_i_7_0, ins_z_6_-1]
# 259                                        [ins_u_4_0]
# 260                  [ins_a_7_0, ins_i_9_2, ins_m_8_1]
# 261                             [ins_w_9_1, ins_ó_8_0]
# 262  [del_e_6_-2, del_k_7_-1, ins_k_6_-2, ins_m_8_0...
# 263                                        [ins_a_4_0]
# 264                             [ins_c_8_0, ins_h_9_1]
#
#                           source                 target
# 0                 Cezar-N_DAT_PL                Cezarom
# 1             Marsjanin-N_VOC_PL              Marsjanie
# 2             Rzymianin-N_GEN_SG             Rzymianina
# 3              Węgierka-N_ESS_PL             Węgierkach
# 4              abecadło-N_ESS_SG               abecadle
# 5            abiturient-N_DAT_PL           abiturientom
# 6                absurd-N_GEN_PL               absurdów
# 7                aceton-N_INS_SG               acetonem
# 8                adwent-N_VOC_PL                adwenty
# 9        adwokat diabła-N_DAT_SG      adwokatowi diabła
# 10                afiks-N_ACC_PL                 afiksy
# 11          aglomeracja-N_INS_PL          aglomeracjami
# 12          akupunktura-N_ESS_PL          akupunkturach
# 13            alabaster-N_VOC_PL              alabastry
# 14             ambulans-N_NOM_PL              ambulansy
# 15             arsenian-N_INS_PL            arsenianami
# 16          arystokrata-N_INS_PL          arystokratami
# 17               ateusz-N_GEN_SG                ateusza
# 18                atlas-N_DAT_SG               atlasowi
# 19             bagażnik-N_ESS_PL            bagażnikach
# 20             bagażnik-N_NOM_SG               bagażnik
# 21                  bak-N_INS_SG                 bakiem
# 22          bicie piany-N_ESS_SG            biciu piany
# 23           biustonosz-N_ACC_PL            biustonosze
# 24              blondyn-N_ACC_PL              blondynów
# 25                 bohr-N_INS_SG                 bohrem
# 26            brukselka-N_ESS_PL            brukselkach
# 27              brylant-N_INS_PL             brylantami
# 28                bufon-N_VOC_SG                bufonie
# 29               burnus-N_VOC_SG               burnusie
# ..                           ...                    ...
# 235           trójeczka-N_ESS_PL            trójeczkach
# 236             undekan-N_ACC_PL               undekany
# 237         uniwersytet-N_GEN_PL          uniwersytetów
# 238            uraninit-N_VOC_SG             uraninicie
# 239  urlop macierzyński-N_ESS_SG  urlopie macierzyńskim
# 240           widelczyk-N_ESS_SG             widelczyku
# 241              wieprz-N_VOC_PL                wieprze
# 242                wikt-N_INS_PL                wiktami
# 243             więzień-N_ESS_SG                więźniu
# 244                wolt-N_GEN_PL                 woltów
# 245           wrzeciono-N_ACC_PL              wrzeciona
# 246         wykopalisko-N_NOM_PL            wykopaliska
# 247             wypadek-N_VOC_PL                wypadki
# 248             wyżerka-N_INS_PL              wyżerkami
# 249       wózek widłowy-N_ESS_PL      wózkach widłowych
# 250            włamanie-N_ESS_PL             włamaniach
# 251           załącznik-N_INS_PL           załącznikami
# 252             zdjęcie-N_INS_PL              zdjęciami
# 253          zdrajczyni-N_ESS_PL          zdrajczyniach
# 254               zegar-N_VOC_SG                zegarze
# 255            zgrzebło-N_NOM_PL               zgrzebła
# 256              ziarno-N_INS_PL               ziarnami
# 257         zlewozmywak-N_DAT_SG         zlewozmywakowi
# 258              łabędź-N_ACC_SG               łabędzia
# 259                 łuk-N_ESS_SG                   łuku
# 260              śmieci-N_INS_SG              śmieciami
# 261             śpiewak-N_ACC_PL              śpiewaków
# 262             świadek-N_DAT_PL               świadkom
# 263                 Żyd-N_ACC_SG                   Żyda
# 264             żyletka-N_ESS_PL              żyletkach
#
# [265 rows x 3 columns]

# %%
prf_values = list(prf.values())
prf_keys = list(prf.keys())
prf_df = pd.DataFrame.from_dict({'operation': [_.split('_')[0] for _ in prf_keys],
                                 'char': [_.split('_')[1] for _ in prf_keys],
                                 'lpos': [_.split('_')[2] for _ in prf_keys],
                                 'rpos': [_.split('_')[3] for _ in prf_keys],
                                 'precision': [_[0] for _ in prf_values],
                                 'recall': [_[1] for _ in prf_values],
                                 'f_score': [_[2] for _ in prf_values]})
display(prf_df.head())
P = [ e[0] for e in list(prf.values())]
R = [ e[1] for e in list(prf.values())]
F = [ e[2] for e in list(prf.values())]
print(np.mean(P), np.mean(R), np.mean(F))
# Out:
#   char   f_score lpos operation  precision    recall rpos
# 0    a  0.482165   10       del   0.482759  0.481572   -1
# 1    a  0.492159   11       del   0.495146  0.489209   -1
# 2    a  0.492771   12       del   0.492771  0.492771   -1
# 3    a  0.498810   13       del   0.498810  0.498810   -1
# 4    a  0.495808   14       del   0.497596  0.494033   -1
# 0.497092498031 0.496806813752 0.496904135309

# %%
import seaborn as sns
import matplotlib.pyplot as plt
print('Model-wise boxplots for full-length bitstrings')
plt.clf()
box_plot = sns.boxplot(x='operation', y='precision', data=prf_df)
display(box_plot.get_figure())
plt.clf()
box_plot = sns.boxplot(x='operation', y='recall', data=prf_df)
display(box_plot.get_figure())
plt.clf()
box_plot = sns.boxplot(x='operation', y='f_score', data=prf_df)
display(box_plot.get_figure())
plt.clf()
box_plot = sns.boxplot(x='char', y='precision', data=prf_df)
display(box_plot.get_figure())
# Out:
# Model-wise boxplots for full-length bitstrings

# %%
# Load graphs of classifiers
import pickle
import os
from sklearn import tree
LABELS_PATH = 'data/task1/output/labels/'
labels = pickle.load(open(LABELS_PATH + 'polish-train-high.p', 'rb'))
clf_path = 'data/task1/output/prediction/polish-train-high/'
features = pickle.load(open('feature_map_polish.p', 'rb')).keys()
dtrees = [pickle.load(open(clf_path + clf, 'rb')) for clf in os.listdir(clf_path)]
for i, t in enumerate(os.listdir(clf_path)):
    if 'decision_tree.p' not in t:
        continue
    tree.export_graphviz(dtrees[i], out_file='dotfiles/' + t.replace('.p', '.dot'), feature_names=list(features))

# %%
from subprocess import check_call
for dot_f in os.listdir('dotfiles/'):
    check_call(['dot','-Tpng',('dotfiles/' + dot_f),'-o','pngs/' + dot_f.replace('.dot', '.png')])

# %%
for i, t in enumerate(os.listdir(clf_path)):
    if 'decision_tree.p' in t:
        continue
    feature_importances = dtrees[i].feature_importances_
